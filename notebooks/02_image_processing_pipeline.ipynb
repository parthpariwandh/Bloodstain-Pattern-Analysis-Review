# %% [markdown]
# # Image Processing Pipeline\n\nBackground subtraction, thresholding, morphology, and connected-component descriptors.\n

# %%
from bpa.image_pipeline import generate_synthetic_pattern, analyze_pattern\nimg = generate_synthetic_pattern(seed=7,n_elements=420)\nstats = analyze_pattern(img)\nprint({k: stats[k] for k in ['count','elliptical_percent','mean_angle_deg','std_angle_deg']})
