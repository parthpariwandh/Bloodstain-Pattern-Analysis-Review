# %% [markdown]
# # Impact angle estimation\n\nCompares inverse-sine ellipse fitting with the third-order ABSM polynomial from page 15.

# %%
from bpa.impact_angle import traditional_impact_angle_deg, polynomial_impact_angle_deg\nprint('Ellipse angle:', traditional_impact_angle_deg(2.3, 4.6))\nprint('ABSM angle:', polynomial_impact_angle_deg(12.0))\n
