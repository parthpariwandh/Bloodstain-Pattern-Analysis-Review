# %% [markdown]
# # Impact Angle Estimation\n\nClassical inverse-sine and ABSM polynomial comparison.\n

# %%
from bpa.impact_angle import traditional_impact_angle_deg, polynomial_impact_angle_deg, IMPACT_ANGLE_COMPARISON_TABLE\nprint(traditional_impact_angle_deg(2.1,4.7))\nprint(polynomial_impact_angle_deg(12.0))\nprint(IMPACT_ANGLE_COMPARISON_TABLE)
