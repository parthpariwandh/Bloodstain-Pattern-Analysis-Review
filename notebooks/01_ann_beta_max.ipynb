# %% [markdown]
# # ANN β_max (Eq. 9)\n\nExact equation implementation with normalization and sensitivity.\n

# %%
from bpa.ann import predict_beta_max, ovat_sensitivity, LEGACY_BLIND_TEST_TABLE\nimport pandas as pd\nprint('beta', predict_beta_max(3200,500,1.05,450))\nprint(ovat_sensitivity(3200,500,1.05,450))\nprint(pd.DataFrame(LEGACY_BLIND_TEST_TABLE))
