# %% [markdown]
# # ANN β_max model (Eq. 9)\n\nImplements the exact trained equation from page 9 with normalization from page 10. Includes OVAT sensitivity and legacy-model table.

# %%
from bpa.ann import predict_beta_max, ovat_sensitivity, LEGACY_BLIND_TEST_TABLE\nprint('beta_max =', predict_beta_max(3200, 500, 1.05, 450))\nprint('OVAT:', ovat_sensitivity(3200, 500, 1.05, 450))\nprint('legacy table rows:', len(LEGACY_BLIND_TEST_TABLE))\n
