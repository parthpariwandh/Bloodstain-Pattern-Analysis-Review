# %% [markdown]
# # Unified BPA workflow\n\nEnd-to-end demonstration that links ANN prediction, image processing, impact-angle estimation, and probabilistic origin modeling.

# %%
from bpa.ann import predict_beta_max\nfrom bpa.image_pipeline import generate_synthetic_pattern, analyze_pattern\nfrom bpa.probabilistic_roi import estimate_volume_scaling_exponent\nbeta = predict_beta_max(3200, 500, 1.05, 450)\nstats = analyze_pattern(generate_synthetic_pattern(seed=5, n_elements=420))\nprint('beta', beta)\nprint('count', stats['count'])\nprint('scaling', estimate_volume_scaling_exponent())\n
