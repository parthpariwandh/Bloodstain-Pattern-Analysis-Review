# %% [markdown]
# # Unified BPA Workflow\n\nEnd-to-end example from ANN + image processing + probabilistic scaling.\n

# %%
from bpa.ann import predict_beta_max\nfrom bpa.image_pipeline import generate_synthetic_pattern, analyze_pattern\nfrom bpa.probabilistic_roi import estimate_volume_scaling_exponent\nprint(predict_beta_max(3200,500,1.05,450))\nprint(analyze_pattern(generate_synthetic_pattern(seed=4, n_elements=420))['count'])\nprint(estimate_volume_scaling_exponent())
