# %% [markdown]
# # Probabilistic 3-D region of origin\n\nImplements ψ_ik and ϕ_ik(z), then combines them with joint likelihood across stains.

# %%
import numpy as np\nfrom bpa.probabilistic_roi import HeightPdfParams, trajectory_passing_probability, height_pdf, estimate_volume_scaling_exponent\nd = np.linspace(0, 1, 5)\nz = np.linspace(0.6, 1.4, 5)\nprint('psi:', trajectory_passing_probability(d, 0.25))\nprint('phi:', height_pdf(z, HeightPdfParams(1.0, 0.1, 0.3)))\nprint('scaling exponent:', estimate_volume_scaling_exponent())\n
