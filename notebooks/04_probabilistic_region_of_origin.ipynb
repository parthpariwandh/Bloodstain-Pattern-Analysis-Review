# %% [markdown]
# # Probabilistic Region of Origin\n\nImplements ψ_ik and ϕ_ik(z) with Gaussian tails and scaling analysis.\n

# %%
import numpy as np\nfrom bpa.probabilistic_roi import trajectory_passing_probability, height_pdf, HeightPdfParams, estimate_volume_scaling_exponent\nprint(trajectory_passing_probability(np.array([0.0,0.2,0.4]),0.3))\nprint(height_pdf(np.array([0.8,1.0,1.2]), HeightPdfParams(1.0,0.1,0.25)))\nprint(estimate_volume_scaling_exponent())
